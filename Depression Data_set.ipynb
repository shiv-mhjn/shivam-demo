# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv("E:/chrome download/pandas/depression_data.csv")

# %%
df
# Out:
#                     Name  Age Marital Status    Education Level  \
# 0       Christine Barker   31        Married  Bachelor's Degree
# 1       Jacqueline Lewis   55        Married        High School
# 2         Shannon Church   78        Widowed    Master's Degree
# 3         Charles Jordan   58       Divorced    Master's Degree
# 4           Michael Rich   18         Single        High School
# ...                  ...  ...            ...                ...
# 413763       Sean Miller   68        Married    Master's Degree
# 413764   Christina Brown   26         Single  Bachelor's Degree
# 413765   Matthew Jenkins   57        Married  Bachelor's Degree
# 413766     Gary Faulkner   71        Married   Associate Degree
# 413767    Joseph Johnson   62        Widowed    Master's Degree
#
#         Number of Children Smoking Status Physical Activity Level  \
# 0                        2     Non-smoker                  Active
# ...

# %%
# 1st getting basic information about the dataset

# %%
df.head()
# Out:
#                Name  Age Marital Status    Education Level  \
# 0  Christine Barker   31        Married  Bachelor's Degree
# 1  Jacqueline Lewis   55        Married        High School
# 2    Shannon Church   78        Widowed    Master's Degree
# 3    Charles Jordan   58       Divorced    Master's Degree
# 4      Michael Rich   18         Single        High School
#
#    Number of Children Smoking Status Physical Activity Level  \
# 0                   2     Non-smoker                  Active
# 1                   1     Non-smoker               Sedentary
# 2                   1     Non-smoker               Sedentary
# 3                   3     Non-smoker                Moderate
# 4                   0     Non-smoker               Sedentary
#
#   Employment Status     Income Alcohol Consumption Dietary Habits  \
# 0        Unemployed   26265.67            Moderate       Moderate
# 1          Employed   42710.36                High      Unhealthy
# ...

# %%
df.describe()
# Out:
#                  Age  Number of Children         Income
# count  413768.000000       413768.000000  413768.000000
# mean       49.000713            1.298972   50661.707971
# std        18.158759            1.237054   40624.100565
# min        18.000000            0.000000       0.410000
# 25%        33.000000            0.000000   21001.030000
# 50%        49.000000            1.000000   37520.135000
# 75%        65.000000            2.000000   76616.300000
# max        80.000000            4.000000  209995.220000

# %%
#Insight 2 getting the Information of datatypes
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 413768 entries, 0 to 413767
# Data columns (total 16 columns):
#  #   Column                        Non-Null Count   Dtype
# ---  ------                        --------------   -----
#  0   Name                          413768 non-null  object
#  1   Age                           413768 non-null  int64
#  2   Marital Status                413768 non-null  object
#  3   Education Level               413768 non-null  object
#  4   Number of Children            413768 non-null  int64
#  5   Smoking Status                413768 non-null  object
#  6   Physical Activity Level       413768 non-null  object
#  7   Employment Status             413768 non-null  object
#  8   Income                        413768 non-null  float64
#  9   Alcohol Consumption           413768 non-null  object
#  10  Dietary Habits                413768 non-null  object
#  11  Sleep Patterns                413768 non-null  object
# ...

# %%
#Insight 3 checking for duplicated values

df.duplicated().sum()

#df.drop_duplicates()
#Here we can conclude that there is no duplicate value in the dataset
# Out:
# 0

# %%
#Insight 4 counting the exact number of peoples this data have

len(df["Name"].unique())

#Here one thing is to be noticed that there are total 413768 rows of data but there are only 196851 peoples are there and
#have repeated
# Out:
# 196851

# %% [markdown]
# # #Insight 5 calculating repeated value of a person

# %%
df[df["Name"]=="Jacqueline Lewis"].count()
# Out:
# Name                            7
# Age                             7
# Marital Status                  7
# Education Level                 7
# Number of Children              7
# Smoking Status                  7
# Physical Activity Level         7
# Employment Status               7
# Income                          7
# Alcohol Consumption             7
# Dietary Habits                  7
# Sleep Patterns                  7
# History of Mental Illness       7
# History of Substance Abuse      7
# Family History of Depression    7
# Chronic Medical Conditions      7
# dtype: int64

# %%
# here it is noted that the Jacqueline Lewis cames in the dataset 7 times with something different in the each columns and hence
# It was not removed by df.drop_duplicated command

# %% [markdown]
# # Insight 6 grouping the persons on the basis of Employment

# %%
grouped=df.groupby(["Employment Status","Smoking Status"])

# %%
grouped

# %%
import warnings

# %% [markdown]
# # Insight 7 plotting a graph Between Age and Income

# %%
AI= df[["Age","Income"]]

# %%
AI
# Out:
#         Age     Income
# 0        31   26265.67
# 1        55   42710.36
# 2        78  125332.79
# 3        58    9992.78
# 4        18    8595.08
# ...     ...        ...
# 413763   68  109233.43
# 413764   26   96760.97
# 413765   57   77353.26
# 413766   71   24557.08
# 413767   62  107125.74
#
# [413768 rows x 2 columns]

# %%
#sns.barplot(AI,x="Age",y="Income")

# %%
sns.lineplot(data=AI, x='Age', y='Income')
plt.title('Average Income by Age')
plt.show()

# %%
#Here we can conclude that most peoples having Income Between Age of 30 to 45

# %%
df.head()
# Out:
#                Name  Age Marital Status    Education Level  \
# 0  Christine Barker   31        Married  Bachelor's Degree
# 1  Jacqueline Lewis   55        Married        High School
# 2    Shannon Church   78        Widowed    Master's Degree
# 3    Charles Jordan   58       Divorced    Master's Degree
# 4      Michael Rich   18         Single        High School
#
#    Number of Children Smoking Status Physical Activity Level  \
# 0                   2     Non-smoker                  Active
# 1                   1     Non-smoker               Sedentary
# 2                   1     Non-smoker               Sedentary
# 3                   3     Non-smoker                Moderate
# 4                   0     Non-smoker               Sedentary
#
#   Employment Status     Income Alcohol Consumption Dietary Habits  \
# 0        Unemployed   26265.67            Moderate       Moderate
# 1          Employed   42710.36                High      Unhealthy
# ...

# %% [markdown]
# # Insight 8 Getting Information of Those persons who are Divorced

# %%
#sns.lineplot(df,x="Marital Status",y="Alcohol Consumption")

# %%
y=df[["Name"]][df["Marital Status"]=="Divorced"]

# %%
y
# Out:
#                   Name
# 3       Charles Jordan
# 8       Kathryn Taylor
# 29       Benjamin Love
# 40        Eric Sanchez
# 41         Diana Davis
# ...                ...
# 413701    Stephen Holt
# 413704    Robert Moore
# 413735  Darlene Howard
# 413743  Jesus Berg Jr.
# 413744  Justin Hancock
#
# [32729 rows x 1 columns]

# %% [markdown]
# # Insight 9 Plotting a graph between 2 Catagorical data Employment status and sleep Pattern

# %%
df_sleep = df[["Employment Status","Sleep Patterns"]]

# %%
df_sleeps=pd.DataFrame(df_sleep)

# %%
#sns.barplot(df_sleeps,x="Employment Status",hue="Sleep Patterns")

# %% [markdown]
# # Insight 10 calculating the mean Income based on Employment

# %%
avg_income = df.groupby(["Employment Status"])[["Income"]].mean()

# %%
avg_income
# Out:
#                          Income
# Employment Status
# Employed           70526.047302
# Unemployed         15031.594189

# %%
df.head()
# Out:
#                Name  Age Marital Status    Education Level  \
# 0  Christine Barker   31        Married  Bachelor's Degree
# 1  Jacqueline Lewis   55        Married        High School
# 2    Shannon Church   78        Widowed    Master's Degree
# 3    Charles Jordan   58       Divorced    Master's Degree
# 4      Michael Rich   18         Single        High School
#
#    Number of Children Smoking Status Physical Activity Level  \
# 0                   2     Non-smoker                  Active
# 1                   1     Non-smoker               Sedentary
# 2                   1     Non-smoker               Sedentary
# 3                   3     Non-smoker                Moderate
# 4                   0     Non-smoker               Sedentary
#
#   Employment Status     Income Alcohol Consumption Dietary Habits  \
# 0        Unemployed   26265.67            Moderate       Moderate
# 1          Employed   42710.36                High      Unhealthy
# ...

# %% [markdown]
# # Insight 11 Plotting a countplot on Smoking status and Effect on Mental Illness

# %%
import seaborn as sns
import matplotlib.pyplot as plt

sns.countplot(data=df, x='Smoking Status', hue="History of Mental Illness")
plt.title('Smoking Status by History of Mental Illness')
plt.xlabel('Smoking Status')
plt.ylabel('Count')
plt.legend(title='History of Mental Illness')
plt.show()

# %% [markdown]
# # Insight 12 Plotting a Scatterplot between Education Level and Alcohol consumption

# %%
#sns.scatterplot(data=df, x ="Education Level",hue="Alcohol Consumption")
sns.countplot(data=df, x="Education Level",hue="Alcohol Consumption")
plt.title("Alcohol Consumption based on Education")
# Out:
# Text(0.5, 1.0, 'Alcohol Consumption based on Education')

# %% [markdown]
# # Insight 13 Getting the Information about the data

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 413768 entries, 0 to 413767
# Data columns (total 16 columns):
#  #   Column                        Non-Null Count   Dtype
# ---  ------                        --------------   -----
#  0   Name                          413768 non-null  object
#  1   Age                           413768 non-null  int64
#  2   Marital Status                413768 non-null  object
#  3   Education Level               413768 non-null  object
#  4   Number of Children            413768 non-null  int64
#  5   Smoking Status                413768 non-null  object
#  6   Physical Activity Level       413768 non-null  object
#  7   Employment Status             413768 non-null  object
#  8   Income                        413768 non-null  float64
#  9   Alcohol Consumption           413768 non-null  object
#  10  Dietary Habits                413768 non-null  object
#  11  Sleep Patterns                413768 non-null  object
# ...

# %% [markdown]
# # Insight 14 Education Level valuecount

# %%
total=df["Education Level"].value_counts()

# %%
total
# Out:
# Bachelor's Degree    124329
# High School          118927
# Associate Degree      79999
# Master's Degree       73768
# PhD                   16745
# Name: Education Level, dtype: int64

# %% [markdown]
# # Insight 15 Getting Information of Description

# %%
df.describe()
# Out:
#                  Age  Number of Children         Income
# count  413768.000000       413768.000000  413768.000000
# mean       49.000713            1.298972   50661.707971
# std        18.158759            1.237054   40624.100565
# min        18.000000            0.000000       0.410000
# 25%        33.000000            0.000000   21001.030000
# 50%        49.000000            1.000000   37520.135000
# 75%        65.000000            2.000000   76616.300000
# max        80.000000            4.000000  209995.220000
